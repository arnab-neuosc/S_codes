# %%
import json
import os.path as op
import shutil
from pprint import pprint

import mne
from mne.datasets import sample

from mne_bids import (
    BIDSPath,
    make_dataset_description,
    print_dir_tree,
    read_raw_bids,
    write_meg_calibration,
    write_meg_crosstalk,
    write_raw_bids,
)
from mne_bids.stats import count_events

# %%
data_path = sample.data_path()
event_id = {
    "Auditory/Left": 1,
    "Auditory/Right": 2,
    "Visual/Left": 3,
    "Visual/Right": 4,
    "Smiley": 5,
    "Button": 32,
}

raw_fname = op.join(data_path, "MEG", "sample", "sample_audvis_raw.fif")
er_fname = op.join(data_path, "MEG", "sample", "ernoise_raw.fif")  # empty room
events_fname = op.join(data_path, "MEG", "sample", "sample_audvis_raw-eve.fif")
output_path = op.join(data_path, "..", "MNE-sample-data-bids")

# %%
raw = mne.io.read_raw(raw_fname)
raw_er = mne.io.read_raw(er_fname)
# Out:
# Opening raw data file /home/rakshita/mne_data/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Opening raw data file /home/rakshita/mne_data/MNE-sample-data/MEG/sample/ernoise_raw.fif...
# Isotrak not found
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 19800 ... 85867 =     32.966 ...   142.965 secs
# Ready.

# %%
raw.get_channel_types()

# %%
raw.info['chs']
# Out:
# [{'scanno': 1,
#   'logno': 113,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1066    ,  0.0464    , -0.0604    , -0.0127    ,  0.0057    ,
#          -0.99990302, -0.186801  , -0.98240298, -0.0033    , -0.98232698,
#           0.18674099,  0.013541  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0113',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 2,
#   'logno': 112,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1066    ,  0.0464    , -0.0604    , -0.186801  , -0.98240298,
#          -0.0033    ,  0.0127    , -0.0057    ,  0.99990302, -0.98232698,
#           0.18674099,  0.013541  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0112',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 3,
#   'logno': 111,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1066    ,  0.0464    , -0.0604    , -0.0127    ,  0.0057    ,
#          -0.99990302, -0.186801  , -0.98240298, -0.0033    , -0.98232698,
#           0.18674099,  0.013541  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0111',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 4,
#   'logno': 122,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.102     ,  0.0631    , -0.0256    ,  0.0136    ,  0.0011    ,
#          -0.99990201, -0.28200099, -0.95940202, -0.0049    , -0.95931298,
#           0.28203899, -0.012738  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0122',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 5,
#   'logno': 123,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.102     ,  0.0631    , -0.0256    , -0.28200099, -0.95940202,
#          -0.0049    , -0.0136    , -0.0011    ,  0.99990201, -0.95931298,
#           0.28203899, -0.012738  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0123',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 6,
#   'logno': 121,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.102     ,  0.0631    , -0.0256    ,  0.0136    ,  0.0011    ,
#          -0.99990201, -0.28200099, -0.95940202, -0.0049    , -0.95931298,
#           0.28203899, -0.012738  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0121',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 7,
#   'logno': 132,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1085    ,  0.0302    , -0.0266    ,  0.0026    ,  0.0023    ,
#          -0.999955  , -0.095196  , -0.99545598, -0.0025    , -0.995417  ,
#           0.095198  , -0.002369  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0132',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 8,
#   'logno': 133,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1085    ,  0.0302    , -0.0266    , -0.095196  , -0.99545598,
#          -0.0025    , -0.0026    , -0.0023    ,  0.999955  , -0.995417  ,
#           0.095198  , -0.002369  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0133',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 9,
#   'logno': 131,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1085    ,  0.0302    , -0.0266    ,  0.0026    ,  0.0023    ,
#          -0.999955  , -0.095196  , -0.99545598, -0.0025    , -0.995417  ,
#           0.095198  , -0.002369  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0131',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 10,
#   'logno': 143,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1099    ,  0.0131    , -0.0627    , -0.0123    ,  0.0018    ,
#          -0.99992299, -0.0212    , -0.99982297, -0.0016    , -0.99974799,
#           0.021179  ,  0.012336  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0143',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 11,
#   'logno': 142,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1099    ,  0.0131    , -0.0627    , -0.0212    , -0.99982297,
#          -0.0016    ,  0.0123    , -0.0018    ,  0.99992299, -0.99974799,
#           0.021179  ,  0.012336  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0142',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 12,
#   'logno': 141,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1099    ,  0.0131    , -0.0627    , -0.0123    ,  0.0018    ,
#          -0.99992299, -0.0212    , -0.99982297, -0.0016    , -0.99974799,
#           0.021179  ,  0.012336  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0141',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 13,
#   'logno': 213,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1074    ,  0.0329    ,  0.008     , -0.051198  ,  0.0077    ,
#          -0.99865901, -0.101496  , -0.99475902, -0.0025    , -0.99344403,
#           0.101232  ,  0.051711  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0213',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 14,
#   'logno': 212,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1074    ,  0.0329    ,  0.008     , -0.101496  , -0.99475902,
#          -0.0025    ,  0.051198  , -0.0077    ,  0.99865901, -0.99344403,
#           0.101232  ,  0.051711  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0212',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 15,
#   'logno': 211,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1074    ,  0.0329    ,  0.008     , -0.051198  ,  0.0077    ,
#          -0.99865901, -0.101496  , -0.99475902, -0.0025    , -0.99344403,
#           0.101232  ,  0.051711  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0211',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 16,
#   'logno': 222,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0989    ,  0.0403    ,  0.0413    , -0.34320599,  0.059801  ,
#          -0.937415  , -0.16180301, -0.98681599, -0.0037    , -0.92527801,
#           0.150406  ,  0.34835699]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0222',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 17,
#   'logno': 223,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0989    ,  0.0403    ,  0.0413    , -0.16180301, -0.98681599,
#          -0.0037    ,  0.34320599, -0.059801  ,  0.937415  , -0.92527801,
#           0.150406  ,  0.34835699]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0223',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 18,
#   'logno': 221,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0989    ,  0.0403    ,  0.0413    , -0.34320599,  0.059801  ,
#          -0.937415  , -0.16180301, -0.98681599, -0.0037    , -0.92527801,
#           0.150406  ,  0.34835699]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0221',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 19,
#   'logno': 232,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1011    ,  0.0044    ,  0.0408    , -0.35210299,  0.0087    ,
#          -0.93590802,  0.0378    , -0.99900901, -0.0235    , -0.93518502,
#          -0.043652  ,  0.35142499]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0232',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 20,
#   'logno': 233,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1011    ,  0.0044    ,  0.0408    ,  0.0378    , -0.99900901,
#          -0.0235    ,  0.35210299, -0.0087    ,  0.93590802, -0.93518502,
#          -0.043652  ,  0.35142499]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0233',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 21,
#   'logno': 231,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1011    ,  0.0044    ,  0.0408    , -0.35210299,  0.0087    ,
#          -0.93590802,  0.0378    , -0.99900901, -0.0235    , -0.93518502,
#          -0.043652  ,  0.35142499]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0231',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 22,
#   'logno': 243,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1083    , -0.0011    ,  0.0071    , -0.067199  , -0.0104    ,
#          -0.99768502,  0.084999  , -0.99638599,  0.0047    , -0.99412799,
#          -0.084486  ,  0.06784   ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0243',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 23,
#   'logno': 242,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1083    , -0.0011    ,  0.0071    ,  0.084999  , -0.99638599,
#           0.0047    ,  0.067199  ,  0.0104    ,  0.99768502, -0.99412799,
#          -0.084486  ,  0.06784   ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0242',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 24,
#   'logno': 241,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1083    , -0.0011    ,  0.0071    , -0.067199  , -0.0104    ,
#          -0.99768502,  0.084999  , -0.99638599,  0.0047    , -0.99412799,
#          -0.084486  ,  0.06784   ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0241',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 25,
#   'logno': 313,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0861    ,  0.0988    ,  0.009     , -0.035199  ,  0.118196  ,
#          -0.99236602, -0.48358399, -0.87097001, -0.086597  , -0.87455702,
#           0.47684401,  0.087815  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0313',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 26,
#   'logno': 312,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0861    ,  0.0988    ,  0.009     , -0.48358399, -0.87097001,
#          -0.086597  ,  0.035199  , -0.118196  ,  0.99236602, -0.87455702,
#           0.47684401,  0.087815  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0312',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 27,
#   'logno': 311,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0861    ,  0.0988    ,  0.009     , -0.035199  ,  0.118196  ,
#          -0.99236602, -0.48358399, -0.87097001, -0.086597  , -0.87455702,
#           0.47684401,  0.087815  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0311',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 28,
#   'logno': 322,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0887    ,  0.0757    ,  0.0412    , -0.351594  ,  0.118898  ,
#          -0.92858398, -0.370994  , -0.92838401,  0.0216    , -0.85951501,
#           0.35209301,  0.370525  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0322',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 29,
#   'logno': 323,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0887    ,  0.0757    ,  0.0412    , -0.370994  , -0.92838401,
#           0.0216    ,  0.351594  , -0.118898  ,  0.92858398, -0.85951501,
#           0.35209301,  0.370525  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0323',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 30,
#   'logno': 321,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0887    ,  0.0757    ,  0.0412    , -0.351594  ,  0.118898  ,
#          -0.92858398, -0.370994  , -0.92838401,  0.0216    , -0.85951501,
#           0.35209301,  0.370525  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0321',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 31,
#   'logno': 333,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0702    ,  0.0758    ,  0.0707    , -0.59424001,  0.228816  ,
#          -0.771052  , -0.385726  , -0.92236298,  0.023502  , -0.70581198,
#           0.31138101,  0.636365  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0333',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 32,
#   'logno': 332,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0702    ,  0.0758    ,  0.0707    , -0.385726  , -0.92236298,
#           0.023502  ,  0.59424001, -0.228816  ,  0.771052  , -0.70581198,
#           0.31138101,  0.636365  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0332',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 33,
#   'logno': 331,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0702    ,  0.0758    ,  0.0707    , -0.59424001,  0.228816  ,
#          -0.771052  , -0.385726  , -0.92236298,  0.023502  , -0.70581198,
#           0.31138101,  0.636365  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0331',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 34,
#   'logno': 343,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1003    ,  0.0659    ,  0.0081    , -0.065802  ,  0.024701  ,
#          -0.997527  , -0.28830799, -0.95752603, -0.0047    , -0.95527399,
#           0.28728601,  0.070128  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0343',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 35,
#   'logno': 342,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.1003    ,  0.0659    ,  0.0081    , -0.28830799, -0.95752603,
#          -0.0047    ,  0.065802  , -0.024701  ,  0.997527  , -0.95527399,
#           0.28728601,  0.070128  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0342',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 36,
#   'logno': 341,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.1003    ,  0.0659    ,  0.0081    , -0.065802  ,  0.024701  ,
#          -0.997527  , -0.28830799, -0.95752603, -0.0047    , -0.95527399,
#           0.28728601,  0.070128  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0341',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 37,
#   'logno': 413,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0808    ,  0.0413    ,  0.072     , -0.64212602,  0.049002  ,
#          -0.76503098, -0.13570599, -0.98953998,  0.050502  , -0.75455499,
#           0.13624801,  0.64205998]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0413',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 38,
#   'logno': 412,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0808    ,  0.0413    ,  0.072     , -0.13570599, -0.98953998,
#           0.050502  ,  0.64212602, -0.049002  ,  0.76503098, -0.75455499,
#           0.13624801,  0.64205998]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0412',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 39,
#   'logno': 411,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0808    ,  0.0413    ,  0.072     , -0.64212602,  0.049002  ,
#          -0.76503098, -0.13570599, -0.98953998,  0.050502  , -0.75455499,
#           0.13624801,  0.64205998]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0411',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 40,
#   'logno': 422,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0526    ,  0.0406    ,  0.0952    , -0.87497002, -0.019699  ,
#          -0.48378301, -0.054998  , -0.988666  ,  0.139695  , -0.48105201,
#           0.148836  ,  0.86396998]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0422',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 41,
#   'logno': 423,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0526    ,  0.0406    ,  0.0952    , -0.054998  , -0.988666  ,
#           0.139695  ,  0.87497002,  0.019699  ,  0.48378301, -0.48105201,
#           0.148836  ,  0.86396998]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0423',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 42,
#   'logno': 421,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0526    ,  0.0406    ,  0.0952    , -0.87497002, -0.019699  ,
#          -0.48378301, -0.054998  , -0.988666  ,  0.139695  , -0.48105201,
#           0.148836  ,  0.86396998]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0421',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 43,
#   'logno': 432,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0537    ,  0.0059    ,  0.0969    , -0.87026697, -0.017799  ,
#          -0.49208099,  0.028999  , -0.99946201, -0.015299  , -0.49154499,
#          -0.027584  ,  0.87031502]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0432',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 44,
#   'logno': 433,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0537    ,  0.0059    ,  0.0969    ,  0.028999  , -0.99946201,
#          -0.015299  ,  0.87026697,  0.017799  ,  0.49208099, -0.49154499,
#          -0.027584  ,  0.87031502]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0433',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 45,
#   'logno': 431,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0537    ,  0.0059    ,  0.0969    , -0.87026697, -0.017799  ,
#          -0.49208099,  0.028999  , -0.99946201, -0.015299  , -0.49154499,
#          -0.027584  ,  0.87031502]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0431',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 46,
#   'logno': 443,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0829    ,  0.0062    ,  0.0728    , -0.64731598,  0.0021    ,
#          -0.76221901,  0.043201  , -0.99832499, -0.039401  , -0.76102501,
#          -0.058434  ,  0.64614099]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0443',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 47,
#   'logno': 442,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0829    ,  0.0062    ,  0.0728    ,  0.043201  , -0.99832499,
#          -0.039401  ,  0.64731598, -0.0021    ,  0.76221901, -0.76102501,
#          -0.058434  ,  0.64614099]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0442',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 48,
#   'logno': 441,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0829    ,  0.0062    ,  0.0728    , -0.64731598,  0.0021    ,
#          -0.76221901,  0.043201  , -0.99832499, -0.039401  , -0.76102501,
#          -0.058434  ,  0.64614099]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0441',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 49,
#   'logno': 513,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0637    ,  0.12540001,  0.0136    ,  0.0194    ,  0.21690001,
#          -0.97600102, -0.78350103, -0.603001  , -0.1496    , -0.62097698,
#           0.7676    ,  0.158243  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0513',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 50,
#   'logno': 512,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0637    ,  0.12540001,  0.0136    , -0.78350103, -0.603001  ,
#          -0.1496    , -0.0194    , -0.21690001,  0.97600102, -0.62097698,
#           0.7676    ,  0.158243  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0512',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 51,
#   'logno': 511,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0637    ,  0.12540001,  0.0136    ,  0.0194    ,  0.21690001,
#          -0.97600102, -0.78350103, -0.603001  , -0.1496    , -0.62097698,
#           0.7676    ,  0.158243  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0511',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 52,
#   'logno': 523,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0332    ,  0.1397    ,  0.0174    ,  0.0106    ,  0.218707  ,
#          -0.97573298, -0.95703202, -0.280709  , -0.073302  , -0.289929  ,
#           0.93458498,  0.20633399]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0523',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 53,
#   'logno': 522,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0332    ,  0.1397    ,  0.0174    , -0.95703202, -0.280709  ,
#          -0.073302  , -0.0106    , -0.218707  ,  0.97573298, -0.289929  ,
#           0.93458498,  0.20633399]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0522',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 54,
#   'logno': 521,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0332    ,  0.1397    ,  0.0174    ,  0.0106    ,  0.218707  ,
#          -0.97573298, -0.95703202, -0.280709  , -0.073302  , -0.289929  ,
#           0.93458498,  0.20633399]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0521',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 55,
#   'logno': 532,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0337    ,  0.1274    ,  0.0485    , -0.052299  ,  0.470092  ,
#          -0.88108402, -0.962183  , -0.259895  , -0.081599  , -0.267349  ,
#           0.84349698,  0.46590701]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0532',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 56,
#   'logno': 533,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0337    ,  0.1274    ,  0.0485    , -0.962183  , -0.259895  ,
#          -0.081599  ,  0.052299  , -0.470092  ,  0.88108402, -0.267349  ,
#           0.84349698,  0.46590701]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0533',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 57,
#   'logno': 531,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0337    ,  0.1274    ,  0.0485    , -0.052299  ,  0.470092  ,
#          -0.88108402, -0.962183  , -0.259895  , -0.081599  , -0.267349  ,
#           0.84349698,  0.46590701]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0531',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 58,
#   'logno': 542,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0672    ,  0.1089    ,  0.0443    , -0.17119101,  0.37777999,
#          -0.90985203, -0.70996302, -0.68766397, -0.15189201, -0.68305498,
#           0.619959  ,  0.385932  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0542',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 59,
#   'logno': 543,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0672    ,  0.1089    ,  0.0443    , -0.70996302, -0.68766397,
#          -0.15189201,  0.17119101, -0.37777999,  0.90985203, -0.68305498,
#           0.619959  ,  0.385932  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0543',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 60,
#   'logno': 541,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0672    ,  0.1089    ,  0.0443    , -0.17119101,  0.37777999,
#          -0.90985203, -0.70996302, -0.68766397, -0.15189201, -0.68305498,
#           0.619959  ,  0.385932  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0541',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 61,
#   'logno': 613,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0358    ,  0.1048    ,  0.075     , -0.0095    ,  0.77080297,
#          -0.637003  , -0.95460403, -0.196601  , -0.223701  , -0.297665  ,
#           0.60596001,  0.737679  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0613',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 62,
#   'logno': 612,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0358    ,  0.1048    ,  0.075     , -0.95460403, -0.196601  ,
#          -0.223701  ,  0.0095    , -0.77080297,  0.637003  , -0.297665  ,
#           0.60596001,  0.737679  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0612',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 63,
#   'logno': 611,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0358    ,  0.1048    ,  0.075     , -0.0095    ,  0.77080297,
#          -0.637003  , -0.95460403, -0.196601  , -0.223701  , -0.297665  ,
#           0.60596001,  0.737679  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0611',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 64,
#   'logno': 622,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  7.75000006e-02,  9.66999978e-02,  1.99999995e-04,
#           9.17699993e-01, -3.97399992e-01, -1.00000000e+00,  3.99999990e-04,
#           1.99999995e-04,  3.42000014e-04,  3.97399992e-01,  9.17699993e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0622',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 65,
#   'logno': 623,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  7.75000006e-02,  9.66999978e-02, -1.00000000e+00,
#           3.99999990e-04,  1.99999995e-04, -1.99999995e-04, -9.17699993e-01,
#           3.97399992e-01,  3.42000014e-04,  3.97399992e-01,  9.17699993e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0623',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 66,
#   'logno': 621,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 9.99999975e-05,  7.75000006e-02,  9.66999978e-02,  1.99999995e-04,
#           9.17699993e-01, -3.97399992e-01, -1.00000000e+00,  3.99999990e-04,
#           1.99999995e-04,  3.42000014e-04,  3.97399992e-01,  9.17699993e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0621',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 67,
#   'logno': 633,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0184    ,  0.044     ,  0.1063    ,  0.0067    ,  0.98366302,
#          -0.179893  , -0.99006301, -0.018599  , -0.13909499, -0.140168  ,
#           0.179038  ,  0.973764  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0633',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 68,
#   'logno': 632,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0184    ,  0.044     ,  0.1063    , -0.99006301, -0.018599  ,
#          -0.13909499, -0.0067    , -0.98366302,  0.179893  , -0.140168  ,
#           0.179038  ,  0.973764  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0632',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 69,
#   'logno': 631,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0184    ,  0.044     ,  0.1063    ,  0.0067    ,  0.98366302,
#          -0.179893  , -0.99006301, -0.018599  , -0.13909499, -0.140168  ,
#           0.179038  ,  0.973764  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0631',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 70,
#   'logno': 642,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0368    ,  0.0753    ,  0.0922    , -0.025099  ,  0.89645898,
#          -0.44238001, -0.95085698, -0.157993  , -0.26628801, -0.30860901,
#           0.413957  ,  0.85636997]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0642',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 71,
#   'logno': 643,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0368    ,  0.0753    ,  0.0922    , -0.95085698, -0.157993  ,
#          -0.26628801,  0.025099  , -0.89645898,  0.44238001, -0.30860901,
#           0.413957  ,  0.85636997]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0643',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 72,
#   'logno': 641,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0368    ,  0.0753    ,  0.0922    , -0.025099  ,  0.89645898,
#          -0.44238001, -0.95085698, -0.157993  , -0.26628801, -0.30860901,
#           0.413957  ,  0.85636997]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0641',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 73,
#   'logno': 713,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0185    ,  0.0105    ,  0.1096    , -0.990008  , -0.012     ,
#          -0.14050101,  0.0137    , -0.99980801, -0.0114    , -0.14033701,
#          -0.013211  ,  0.98998201]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0713',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 74,
#   'logno': 712,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0185    ,  0.0105    ,  0.1096    ,  0.0137    , -0.99980801,
#          -0.0114    ,  0.990008  ,  0.012     ,  0.14050101, -0.14033701,
#          -0.013211  ,  0.98998201]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0712',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 75,
#   'logno': 711,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0185    ,  0.0105    ,  0.1096    , -0.990008  , -0.012     ,
#          -0.14050101,  0.0137    , -0.99980801, -0.0114    , -0.14033701,
#          -0.013211  ,  0.98998201]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0711',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 76,
#   'logno': 723,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0186    ,  0.0105    ,  0.1096    ,  0.98875201, -0.0072    ,
#          -0.14939301,  0.0011    ,  0.99915099, -0.040798  ,  0.14956   ,
#           0.040175  ,  0.987921  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0723',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 77,
#   'logno': 722,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0186    ,  0.0105    ,  0.1096    ,  0.0011    ,  0.99915099,
#          -0.040798  , -0.98875201,  0.0072    ,  0.14939301,  0.14956   ,
#           0.040175  ,  0.987921  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0722',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 78,
#   'logno': 721,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 0.0186    ,  0.0105    ,  0.1096    ,  0.98875201, -0.0072    ,
#          -0.14939301,  0.0011    ,  0.99915099, -0.040798  ,  0.14956   ,
#           0.040175  ,  0.987921  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0721',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 79,
#   'logno': 733,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0186    , -0.0233    ,  0.1059    , -0.0366    , -0.97030503,
#          -0.23910099,  0.98720503,  0.0021    , -0.159701  ,  0.155461  ,
#          -0.241887  ,  0.95781201]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0733',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 80,
#   'logno': 732,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0186    , -0.0233    ,  0.1059    ,  0.98720503,  0.0021    ,
#          -0.159701  ,  0.0366    ,  0.97030503,  0.23910099,  0.155461  ,
#          -0.241887  ,  0.95781201]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0732',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 81,
#   'logno': 731,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 0.0186    , -0.0233    ,  0.1059    , -0.0366    , -0.97030503,
#          -0.23910099,  0.98720503,  0.0021    , -0.159701  ,  0.155461  ,
#          -0.241887  ,  0.95781201]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0731',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 82,
#   'logno': 743,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0185    , -0.0237    ,  0.1058    ,  0.039398  , -0.96975303,
#          -0.240888  ,  0.99285197,  0.010799  ,  0.118594  , -0.112406  ,
#          -0.243839  ,  0.96324599]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0743',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 83,
#   'logno': 742,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([-0.0185    , -0.0237    ,  0.1058    ,  0.99285197,  0.010799  ,
#           0.118594  , -0.039398  ,  0.96975303,  0.240888  , -0.112406  ,
#          -0.243839  ,  0.96324599]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0742',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 84,
#   'logno': 741,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([-0.0185    , -0.0237    ,  0.1058    ,  0.039398  , -0.96975303,
#          -0.240888  ,  0.99285197,  0.010799  ,  0.118594  , -0.112406  ,
#          -0.243839  ,  0.96324599]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0741',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 85,
#   'logno': 813,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  1.44500002e-01,  1.86999999e-02, -3.00000014e-04,
#           2.51700997e-01, -9.67805028e-01, -9.99904990e-01, -1.20999999e-02,
#          -2.79999990e-03, -1.24150002e-02,  9.67711985e-01,  2.51681000e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0813',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 86,
#   'logno': 812,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  1.44500002e-01,  1.86999999e-02, -9.99904990e-01,
#          -1.20999999e-02, -2.79999990e-03,  3.00000014e-04, -2.51700997e-01,
#           9.67805028e-01, -1.24150002e-02,  9.67711985e-01,  2.51681000e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0812',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 87,
#   'logno': 811,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 9.99999975e-05,  1.44500002e-01,  1.86999999e-02, -3.00000014e-04,
#           2.51700997e-01, -9.67805028e-01, -9.99904990e-01, -1.20999999e-02,
#          -2.79999990e-03, -1.24150002e-02,  9.67711985e-01,  2.51681000e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0811',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 88,
#   'logno': 822,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  1.31600007e-01,  5.00000007e-02,  6.99999975e-04,
#           4.99199986e-01, -8.66500020e-01, -1.00000000e+00,  8.99999985e-04,
#          -1.99999995e-04,  6.79999997e-04,  8.66500020e-01,  4.99199986e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0822',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 89,
#   'logno': 823,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': -3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 9.99999975e-05,  1.31600007e-01,  5.00000007e-02, -1.00000000e+00,
#           8.99999985e-04, -1.99999995e-04, -6.99999975e-04, -4.99199986e-01,
#           8.66500020e-01,  6.79999997e-04,  8.66500020e-01,  4.99199986e-01]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0823',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 90,
#   'logno': 821,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 9.99999975e-05,  1.31600007e-01,  5.00000007e-02,  6.99999975e-04,
#           4.99199986e-01, -8.66500020e-01, -1.00000000e+00,  8.99999985e-04,
#          -1.99999995e-04,  6.79999997e-04,  8.66500020e-01,  4.99199986e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0821',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 91,
#   'logno': 913,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0331    ,  0.1397    ,  0.0173    , -0.0053    ,  0.236504  ,
#          -0.97161603, -0.96471602,  0.25480399,  0.067301  ,  0.26348901,
#           0.93769002,  0.226809  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0913',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 92,
#   'logno': 912,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0331    ,  0.1397    ,  0.0173    , -0.96471602,  0.25480399,
#           0.067301  ,  0.0053    , -0.236504  ,  0.97161603,  0.26348901,
#           0.93769002,  0.226809  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0912',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 93,
#   'logno': 911,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 0.0331    ,  0.1397    ,  0.0173    , -0.0053    ,  0.236504  ,
#          -0.97161603, -0.96471602,  0.25480399,  0.067301  ,  0.26348901,
#           0.93769002,  0.226809  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0911',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 94,
#   'logno': 923,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0638    ,  0.12530001,  0.0135    , -0.022801  ,  0.216906  ,
#          -0.97592598, -0.79242098,  0.59131598,  0.150004  ,  0.60961699,
#           0.77676499,  0.158398  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0923',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 95,
#   'logno': 922,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0638    ,  0.12530001,  0.0135    , -0.79242098,  0.59131598,
#           0.150004  ,  0.022801  , -0.216906  ,  0.97592598,  0.60961699,
#           0.77676499,  0.158398  ]),
#   'unit': 201 (FIFF_UNIT_T_M),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0922',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 96,
#   'logno': 921,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 4.1400001482561066e-11,
#   'coil_type': 3024 (FIFFV_COIL_VV_MAG_T3),
#   'loc': array([ 0.0638    ,  0.12530001,  0.0135    , -0.022801  ,  0.216906  ,
#          -0.97592598, -0.79242098,  0.59131598,  0.150004  ,  0.60961699,
#           0.77676499,  0.158398  ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'MEG 0921',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 97,
#   'logno': 932,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 0.00030517578125,
#   'cal': 3.1600000394149674e-09,
#   'coil_type': 3012 (FIFFV_COIL_VV_PLANAR_T1),
#   'loc': array([ 0.0671    ,  0.1088    ,  0.0444    ,  0.174311  ,  0.37642401,
# ...
#   'loc': array([-0.06942309,  0.00667641,  0.11536647,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 028',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 344,
#   'logno': 29,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019469999824650586,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.04659409,  0.01014391,  0.13405654,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 029',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 345,
#   'logno': 30,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019540000357665122,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.01629983,  0.00927559,  0.14519522,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 030',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 346,
#   'logno': 31,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001866999955382198,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.01318771,  0.01186019,  0.14529571,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 031',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 347,
#   'logno': 32,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019880000036209822,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.04154002,  0.00885528,  0.13335077,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 032',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 348,
#   'logno': 33,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019750000501517206,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.06625186,  0.00735602,  0.10804822,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 033',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 349,
#   'logno': 34,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001947999990079552,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 7.83490464e-02,  5.67555020e-04,  7.73945302e-02,  2.35201186e-03,
#           1.10969514e-01, -3.50045823e-02,  0.00000000e+00,  1.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 034',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 350,
#   'logno': 35,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019370000518392771,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.08234884, -0.01146096,  0.05360142,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 035',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 351,
#   'logno': 36,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001981999957934022,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.0785085 , -0.03574997,  0.03009207,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 036',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 352,
#   'logno': 37,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019449999672360718,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.07721485, -0.02775142,  0.05707676,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 037',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 353,
#   'logno': 38,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.000182100004167296,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.06763091, -0.01491976,  0.11265494,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 038',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 354,
#   'logno': 39,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019299999985378236,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.04704428, -0.02253841,  0.13219631,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 039',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 355,
#   'logno': 40,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019239999528508633,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.01283492, -0.01805472,  0.1434515 ,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 040',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 356,
#   'logno': 41,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00020549999317154288,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.04291361, -0.0194277 ,  0.12802231,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 041',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 357,
#   'logno': 42,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001875000016298145,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.06961878, -0.02327093,  0.08484317,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 042',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 358,
#   'logno': 43,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00018899999849963933,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.07297385, -0.03694624,  0.05249463,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 043',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 359,
#   'logno': 44,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019299999985378236,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.07061125, -0.0511283 ,  0.06498735,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 044',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 360,
#   'logno': 45,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001976000057766214,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.06437745, -0.04527977,  0.0883803 ,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 045',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 361,
#   'logno': 46,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00018180000188294798,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.05353214, -0.04353803,  0.10910925,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 046',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 362,
#   'logno': 47,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019779999274760485,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.0377494 , -0.04685587,  0.11972748,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 047',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 363,
#   'logno': 48,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019039999460801482,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.0127069 , -0.04560889,  0.12729953,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 048',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 364,
#   'logno': 49,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019859999883919954,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.01262307, -0.04997328,  0.12438973,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 049',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 365,
#   'logno': 50,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019540000357665122,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.03226272, -0.04356402,  0.12176917,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 050',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 366,
#   'logno': 51,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00018950000230688602,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.04813613, -0.04604408,  0.10710171,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 051',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 367,
#   'logno': 52,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00020110000332351774,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.06049734, -0.04649068,  0.08270058,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 052',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 368,
#   'logno': 53,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0002043999993475154,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.05508941, -0.06146309,  0.06487645,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 053',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 369,
#   'logno': 54,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.0001905999961309135,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.0477659 , -0.06652118,  0.08565747,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 054',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 370,
#   'logno': 55,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019360000442247838,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.02660348, -0.06446433,  0.10452283,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 055',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 371,
#   'logno': 56,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019540000357665122,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.04204336, -0.06984496,  0.08102813,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 056',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 372,
#   'logno': 57,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00018659999477677047,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.03705651, -0.07594676,  0.07641642,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 057',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 373,
#   'logno': 58,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00018699999782256782,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.0083054 , -0.08009383,  0.08097374,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 058',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 374,
#   'logno': 59,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00020049999875482172,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([ 0.01903442, -0.07699308,  0.08544408,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 059',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 375,
#   'logno': 60,
#   'kind': 2 (FIFFV_EEG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.00019160000374540687,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([-0.00915191, -0.08856268,  0.04415122,  0.00235201,  0.11096951,
#          -0.03500458,  0.        ,  1.        ,  0.        ,  0.        ,
#           0.        ,  1.        ]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EEG 060',
#   'coord_frame': 4 (FIFFV_COORD_HEAD)},
#  {'scanno': 376,
#   'logno': 61,
#   'kind': 202 (FIFFV_EOG_CH),
#   'range': 0.00030517578125,
#   'cal': 0.002142000012099743,
#   'coil_type': 1 (FIFFV_COIL_EEG),
#   'loc': array([0., 0., 0., 1., 0., 0., 0., 1., 0., 0., 0., 1.]),
#   'unit': 107 (FIFF_UNIT_V),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'EOG 061',
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN)}]

# %%
# specify power line frequency as required by BIDS
raw.info["line_freq"] = 60
raw_er.info["line_freq"] = 60

task = "audiovisual"
bids_path = BIDSPath(
    subject="01", session="01", task=task, run="1", datatype="meg", root=output_path
)
write_raw_bids(
    raw=raw,
    bids_path=bids_path,
    events=events_fname,
    event_id=event_id,
    empty_room=raw_er,
    overwrite=True,
)
# Out:
# Opening raw data file /home/rakshita/mne_data/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Opening raw data file /home/rakshita/mne_data/MNE-sample-data/MEG/sample/ernoise_raw.fif...
# Isotrak not found
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 19800 ... 85867 =     32.966 ...   142.965 secs
# Ready.
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/README'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/participants.tsv'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/participants.json'...
# Writing of electrodes.tsv is not supported for data type "meg". Skipping ...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/dataset_description.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/meg/sub-emptyroom_ses-20021206_task-noise_meg.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/meg/sub-emptyroom_ses-20021206_task-noise_channels.tsv'...
# Copying data files to sub-emptyroom_ses-20021206_task-noise_meg.fif
# Reserving possible split file sub-emptyroom_ses-20021206_task-noise_split-01_meg.fif
# Writing /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/meg/sub-emptyroom_ses-20021206_task-noise_meg.fif
# Closing /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/meg/sub-emptyroom_ses-20021206_task-noise_meg.fif
# [done]
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/sub-emptyroom_ses-20021206_scans.tsv'...
# Wrote /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-emptyroom/ses-20021206/sub-emptyroom_ses-20021206_scans.tsv entry with meg/sub-emptyroom_ses-20021206_task-noise_meg.fif.
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/participants.tsv'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/participants.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_coordsystem.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_coordsystem.json'...
# Used Annotations descriptions: ['Auditory/Left', 'Auditory/Right', 'Button', 'Smiley', 'Visual/Left', 'Visual/Right']
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_events.tsv'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_events.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/dataset_description.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_meg.json'...
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_channels.tsv'...
# Copying data files to sub-01_ses-01_task-audiovisual_run-1_meg.fif
# Reserving possible split file sub-01_ses-01_task-audiovisual_run-1_split-01_meg.fif
# Writing /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_meg.fif
# Closing /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/meg/sub-01_ses-01_task-audiovisual_run-1_meg.fif
# [done]
# Writing '/home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/sub-01_ses-01_scans.tsv'...
# Wrote /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids/sub-01/ses-01/sub-01_ses-01_scans.tsv entry with meg/sub-01_ses-01_task-audiovisual_run-1_meg.fif.
# BIDSPath(
# root: /home/rakshita/mne_data/MNE-sample-data/../MNE-sample-data-bids
# datatype: meg
# basename: sub-01_ses-01_task-audiovisual_run-1_meg.fif)
